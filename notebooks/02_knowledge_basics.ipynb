# %% [markdown]
# # Notebook 2: Knowledge Basics\n\nSimple examples for representing knowledge with Python data structures.

# %%
facts = {\n    "domain": "knowledge-based systems",\n    "tool": "python"\n}\nfacts
